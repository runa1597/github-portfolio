# %% [markdown]
# <a href="https://colab.research.google.com/github/runa1597/github-portfolio/blob/main/Runa_Practice_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\"runa\"")
# Out:
# "runa"

# %%
print("runa\nromana")
# Out:
# runa
# romana

# %% [markdown]
# **varables**

# %%
name ="runa"
age =23
cgpa = 3.10
print("our new student name is" +name)
print("she is currently",age,"years old")
print( name+ " has scored",cgpa,"in her secondary exam")
# Out:
# our new student name isruna
# she is currently 23 years old
# runa has scored 3.1 in her secondary exam

# %% [markdown]
# **Basic Numerical Operations**

# %%
print(3+4)
print(3-4)
print(3*4)
print(3/4)
print(3%4)
# Out:
# 7
# -1
# 12
# 0.75
# 3
# 3

# %%
a=3
b=4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
# Out:
# 7
# -1
# 12
# 0.75
# 3
# 0

# %% [markdown]
# **getting user input**

# %%
name=input("enter your name")
age=input("enter your age")
cgpa=input("enter your cgpa")

print("student information")
print("--------------------")
print("name:  "+name)
print("age:  "+age)
print("cgpa: "+cgpa)
# Out:
# enter your nameruna
# enter your age23
# enter your cgpa3.50
# student information
# --------------------
# name:  runa
# age:  23
# cgpa: 3.50

# %% [markdown]
# **Type Casting**

# %%
num1 = int(input("enter the first number:"))
num2 = int(input("enter the second number:"))

result = (num1)+(num2)
print("the result is",result)

'''

result = int(num1)-int(num2)
print("the result is",result)

result = int(num1)/int(num2)
print("the result is",result)

result = int(num1)*int(num2)
print("the result is",result)

result = int(num1)%int(num2)
print("the result is",result)
'''
# Out:
# enter the first number:4
# enter the second number:5
# the result is 9
# '\n\nresult = int(num1)-int(num2)\nprint("the result is",result)\n\nresult = int(num1)/int(num2)\nprint("the result is",result)\n\nresult = int(num1)*int(num2)\nprint("the result is",result)\n\nresult = int(num1)%int(num2)\nprint("the result is",result)\n'

# %% [markdown]
# **Area  Of A shape**

# %%
base=float(input("enter the base of the triangle:"))
height=float(input("enter the height of the triangle:"))

area=0.5*base*height
print("the area of triangle",area)
# Out:
# enter the base of the triangle:20
# enter the height of the triangle:15
# the area of triangle 150.0

# %%
radius=float(input("enter the base of the radius:"))

area=3.1416*radius*radius
print("area of circle=",area)
# Out:
# enter the base of the radius:5
# area of circle= 78.54
